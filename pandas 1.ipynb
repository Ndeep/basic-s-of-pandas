# %% [markdown]
# # pandas 1

# %%
import pandas as pd

# %%
df=pd.read_csv('nyc_weather.csv',parse_dates=['EST'])#parse_dates convert string data-type into date
df.head(3)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0 2016-01-01           38        23        52                 30.03
# 1 2016-01-02           36        18        46                 30.02
# 2 2016-01-03           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df.Temperature.max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8    2016-01-09
# 9    2016-01-10
# 15   2016-01-16
# 26   2016-01-27
# Name: EST, dtype: datetime64[ns]

# %%
df.WindSpeedMPH=df.WindSpeedMPH.fillna(0)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %% [markdown]
# # pandas 2

# %%
address=[{
    "name":"deep",
    "city":"gurgaon"
},
{
    "name":"deep1",
    "city":"noida"
}
]
df1=pd.DataFrame(address)
df1
# Out:
#     name     city
# 0   deep  gurgaon
# 1  deep1    noida

# %%
#df.Events=df.Events.fillna('Sunny')
df[['EST','Temperature','Events']].head()
# Out:
#          EST  Temperature Events
# 0 2016-01-01           38    NaN
# 1 2016-01-02           36    NaN
# 2 2016-01-03           40    NaN
# 3 2016-01-04           25    NaN
# 4 2016-01-05           20    NaN

# %%
df[['EST','Temperature']][df['Temperature']>30] #option 1
df[df.Temperature>30] #option 2
df[df.Temperature==df.Temperature.max()] # for getting max temp record
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9 2016-01-10           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           0.0             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
weather_data=[
    ('1/1/2019',32.6,'sunny'),
    ('1/1/2020',-9,'snowfall')
]
df_tuple=pd.DataFrame(weather_data,columns=['date','temperature','events'])

# %%
df.set_index('EST',inplace=True)#inplace=True modify current dataframe

# %%
new_df=df.fillna({
    'Events':'Sunny'
})
new_df=new_df.fillna(method='ffill')

# %%
new_df
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 2016-01-01           38        23        52                 30.03
# 2016-01-02           36        18        46                 30.02
# 2016-01-03           40        21        47                 29.86
# 2016-01-04           25         9        44                 30.05
# 2016-01-05           20        -3        41                 30.57
# 2016-01-06           33         4        35                 30.50
# 2016-01-07           39        11        33                 30.28
# 2016-01-08           39        29        64                 30.20
# 2016-01-09           44        38        77                 30.16
# 2016-01-10           50        46        71                 29.59
# 2016-01-11           33         8        37                 29.92
# 2016-01-12           35        15        53                 29.85
# 2016-01-13           26         4        42                 29.94
# 2016-01-14           30        12        47                 29.95
# 2016-01-15           43        31        62                 29.82
# 2016-01-16           47        37        70                 29.52
# 2016-01-17           36        23        66                 29.78
# 2016-01-18           25         6        53                 29.83
# 2016-01-19           22         3        42                 30.03
# 2016-01-20           32        15        49                 30.13
# 2016-01-21           31        11        45                 30.15
# 2016-01-22           26         6        41                 30.21
# 2016-01-23           26        21        78                 29.77
# 2016-01-24           28        11        53                 29.92
# 2016-01-25           34        18        54                 30.25
# 2016-01-26           43        29        56                 30.03
# 2016-01-27           41        22        45                 30.03
# 2016-01-28           37        20        51                 29.90
# 2016-01-29           36        21        50                 29.58
# 2016-01-30           34        16        46                 30.01
# 2016-01-31           46        28        52                 29.90
#
#             VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# EST
# 2016-01-01               10           8.0               0           5
# 2016-01-02               10           7.0               0           3
# 2016-01-03               10           8.0               0           1
# 2016-01-04               10           9.0               0           3
# 2016-01-05               10           5.0               0           0
# 2016-01-06               10           4.0               0           0
# 2016-01-07               10           2.0               0           3
# 2016-01-08               10           4.0               0           8
# 2016-01-09                9           8.0               T           8
# 2016-01-10                4           0.0             1.8           7
# 2016-01-11               10           0.0               0           1
# 2016-01-12               10           6.0               T           4
# 2016-01-13               10          10.0               0           0
# 2016-01-14               10           5.0               T           7
# 2016-01-15                9           5.0               T           2
# 2016-01-16                8           7.0            0.24           7
# 2016-01-17                8           6.0            0.05           6
# 2016-01-18                9          12.0               T           2
# 2016-01-19               10          11.0               0           1
# 2016-01-20               10           6.0               0           2
# 2016-01-21               10           6.0               0           1
# 2016-01-22                9           0.0            0.01           3
# 2016-01-23                1          16.0            2.31           8
# 2016-01-24                8           6.0               T           3
# 2016-01-25               10           3.0               0           2
# 2016-01-26               10           7.0               0           2
# 2016-01-27               10           7.0               T           3
# 2016-01-28               10           5.0               0           1
# 2016-01-29               10           8.0               0           4
# 2016-01-30               10           7.0               0           0
# 2016-01-31               10           5.0               0           0
#
#               Events  WindDirDegrees
# EST
# 2016-01-01     Sunny             281
# 2016-01-02     Sunny             275
# 2016-01-03     Sunny             277
# 2016-01-04     Sunny             345
# 2016-01-05     Sunny             333
# 2016-01-06     Sunny             259
# 2016-01-07     Sunny             293
# 2016-01-08     Sunny              79
# 2016-01-09      Rain              76
# 2016-01-10      Rain             109
# 2016-01-11     Sunny             289
# 2016-01-12     Sunny             235
# 2016-01-13     Sunny             284
# 2016-01-14     Sunny             266
# 2016-01-15     Sunny             101
# 2016-01-16      Rain             340
# 2016-01-17  Fog-Snow             345
# 2016-01-18      Snow             293
# 2016-01-19     Sunny             293
# 2016-01-20     Sunny             302
# 2016-01-21     Sunny             312
# 2016-01-22      Snow              34
# 2016-01-23  Fog-Snow              42
# 2016-01-24      Snow             327
# 2016-01-25     Sunny             286
# 2016-01-26     Sunny             244
# 2016-01-27      Rain             311
# 2016-01-28     Sunny             234
# 2016-01-29     Sunny             298
# 2016-01-30     Sunny             257
# 2016-01-31     Sunny             241
